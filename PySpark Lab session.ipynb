# %%
import OS
os.enivron['PYSPARK_PYTHON'] = 'PYTHON'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import OS
#       2 os.enivron['PYSPARK_PYTHON'] = 'PYTHON'
#
# ModuleNotFoundError: No module named 'OS'

# %%
from pyspark.sql import SparkSession
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pyspark.sql import SparkSession
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pyspark/__init__.py:65
#      63 from pyspark.storagelevel import StorageLevel
#      64 from pyspark.accumulators import Accumulator, AccumulatorParam
# ---> 65 from pyspark.broadcast import Broadcast
#      66 from pyspark.serializers import MarshalSerializer, CPickleSerializer
#      67 from pyspark.taskcontext import TaskContext, BarrierTaskContext, BarrierTaskInfo
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pyspark/broadcast.py:38
#      23 import pickle
#      24 from typing import (
#      25     overload,
#      26     Any,
#    (...)     36     Union,
#      37 )
# ...
